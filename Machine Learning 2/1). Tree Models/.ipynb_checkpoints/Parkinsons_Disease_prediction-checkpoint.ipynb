# %%
# Importing the required libraries
import pandas as pd, numpy as np
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline

# %%
# Reading the csv file and putting it into 'df' object.
df = pd.read_csv('heart.csv')

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df = df.drop_duplicates(ignore_index = True)
df.shape
# Out:
# (302, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
col = df.columns

for col in df.columns:
    print('-' * 40 + col + '-' * 40 , end=' - ')
    display(df[col].value_counts(normalize = True))
# Out:
# ----------------------------------------age---------------------------------------- -
# 58    0.062914
# 57    0.056291
# 54    0.052980
# 59    0.046358
# 52    0.043046
# 51    0.039735
# 62    0.036424
# 44    0.036424
# 60    0.036424
# 56    0.036424
# 64    0.033113
# 41    0.033113
# 63    0.029801
# 67    0.029801
# 55    0.026490
# 45    0.026490
# 42    0.026490
# 53    0.026490
# 61    0.026490
# 65    0.026490
# 43    0.026490
# 66    0.023179
# 50    0.023179
# 48    0.023179
# 46    0.023179
# 49    0.016556
# 47    0.016556
# 39    0.013245
# 35    0.013245
# 68    0.013245
# 70    0.013245
# 40    0.009934
# 71    0.009934
# 69    0.009934
# 34    0.006623
# 37    0.006623
# 38    0.006623
# 77    0.003311
# 76    0.003311
# 74    0.003311
# 29    0.003311
# Name: age, dtype: float64
# ----------------------------------------sex---------------------------------------- -
# 1    0.682119
# 0    0.317881
# Name: sex, dtype: float64
# ----------------------------------------cp---------------------------------------- -
# 0    0.473510
# 2    0.284768
# 1    0.165563
# 3    0.076159
# Name: cp, dtype: float64
# ----------------------------------------trestbps---------------------------------------- -
# 120    0.122517
# 130    0.119205
# 140    0.105960
# 110    0.062914
# 150    0.056291
# 138    0.039735
# 128    0.039735
# 125    0.036424
# 160    0.036424
# 112    0.029801
# 132    0.026490
# 118    0.023179
# 135    0.019868
# 108    0.019868
# 124    0.019868
# 145    0.016556
# 134    0.016556
# 152    0.016556
# 122    0.013245
# 170    0.013245
# 100    0.013245
# 142    0.009934
# 115    0.009934
# 136    0.009934
# 105    0.009934
# 180    0.009934
# 126    0.009934
# 102    0.006623
# 94     0.006623
# 144    0.006623
# 178    0.006623
# 146    0.006623
# 148    0.006623
# 129    0.003311
# 165    0.003311
# 101    0.003311
# 174    0.003311
# 104    0.003311
# 172    0.003311
# 106    0.003311
# 156    0.003311
# 164    0.003311
# 192    0.003311
# 114    0.003311
# 155    0.003311
# 117    0.003311
# 154    0.003311
# 123    0.003311
# 200    0.003311
# Name: trestbps, dtype: float64
# ----------------------------------------chol---------------------------------------- -
# 234    0.019868
# 204    0.019868
# 197    0.019868
# 212    0.016556
# 254    0.016556
#          ...
# 278    0.003311
# 281    0.003311
# 284    0.003311
# 290    0.003311
# 564    0.003311
# Name: chol, Length: 152, dtype: float64
# ----------------------------------------fbs---------------------------------------- -
# 0    0.850993
# 1    0.149007
# Name: fbs, dtype: float64
# ----------------------------------------restecg---------------------------------------- -
# 1    0.500000
# 0    0.486755
# 2    0.013245
# Name: restecg, dtype: float64
# ----------------------------------------thalach---------------------------------------- -
# 162    0.036424
# 160    0.029801
# 163    0.029801
# 152    0.026490
# 173    0.023179
#          ...
# 129    0.003311
# 128    0.003311
# 127    0.003311
# 124    0.003311
# 71     0.003311
# Name: thalach, Length: 91, dtype: float64
# ----------------------------------------exang---------------------------------------- -
# 0    0.672185
# 1    0.327815
# Name: exang, dtype: float64
# ----------------------------------------oldpeak---------------------------------------- -
# 0.0    0.324503
# 1.2    0.056291
# 1.0    0.046358
# 0.6    0.046358
# 0.8    0.043046
# 1.4    0.043046
# 0.2    0.039735
# 1.6    0.036424
# 1.8    0.033113
# 2.0    0.029801
# 0.4    0.029801
# 0.1    0.023179
# 2.6    0.019868
# 2.8    0.019868
# 3.0    0.016556
# 1.5    0.016556
# 1.9    0.016556
# 0.5    0.016556
# 3.6    0.013245
# 2.2    0.013245
# 3.4    0.009934
# 0.3    0.009934
# 4.0    0.009934
# 0.9    0.009934
# 2.4    0.009934
# 1.1    0.006623
# 2.5    0.006623
# 3.2    0.006623
# 2.3    0.006623
# 4.2    0.006623
# 3.1    0.003311
# 1.3    0.003311
# 3.5    0.003311
# 2.9    0.003311
# 6.2    0.003311
# 4.4    0.003311
# 0.7    0.003311
# 5.6    0.003311
# 3.8    0.003311
# 2.1    0.003311
# Name: oldpeak, dtype: float64
# ----------------------------------------slope---------------------------------------- -
# 2    0.466887
# 1    0.463576
# 0    0.069536
# Name: slope, dtype: float64
# ----------------------------------------ca---------------------------------------- -
# 0    0.579470
# 1    0.215232
# 2    0.125828
# 3    0.066225
# 4    0.013245
# Name: ca, dtype: float64
# ----------------------------------------thal---------------------------------------- -
# 2    0.546358
# 3    0.387417
# 1    0.059603
# 0    0.006623
# Name: thal, dtype: float64
# ----------------------------------------target---------------------------------------- -
# 1    0.543046
# 0    0.456954
# Name: target, dtype: float64

# %%
# Putting feature variable to X
X = df.drop('target',axis=1)

# Putting response variable to y
y = df['target']

# %%
from sklearn.model_selection import train_test_spli

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, random_state=42)
X_train.shape, X_test.shape
# Out:
# ((241, 13), (61, 13))

# %% [markdown]
# Fitting the decision tree with default hyperparameters, apart from max_depth which is 3 so that we can plot and read the tree.

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier(max_depth=3)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
# !pip install six
# Out:
# Requirement already satisfied: six in c:\users\nikki\anaconda3\lib\site-packages (1.15.0)

# %%
# Importing required packages for visualization
from IPython.display import Image  
from six import StringIO  
from sklearn.tree import export_graphviz
import pydotplus, graphviz

# %%
# plotting tree with max_depth=3
dot_data = StringIO()  

export_graphviz(dt, out_file=dot_data, filled=True, rounded=True,
                feature_names=X.columns, 
                class_names=['No Disease', "Disease"])

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
#Image(graph.create_png(),width=800,height=900)
#graph.write_pdf("dt_heartdisease.pdf")

# %% [markdown]
# #### Evaluating model performance

# %%
y_train_pred = dt.predict(X_train)
y_test_pred = dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
print(accuracy_score(y_train, y_train_pred))
confusion_matrix(y_train, y_train_pred)
# Out:
# 0.8464730290456431
# array([[ 79,  27],
#        [ 10, 125]], dtype=int64)

# %%
print(accuracy_score(y_test, y_test_pred))
confusion_matrix(y_test, y_test_pred)
# Out:
# 0.7868852459016393
# array([[24,  8],
#        [ 5, 24]], dtype=int64)

# %% [markdown]
# Creating helper functions to evaluate model performance and help plot the decision tree

# %%
def get_dt_graph(dt_classifier):
    dot_data = StringIO()
    export_graphviz(dt_classifier, out_file=dot_data, filled=True,rounded=True,
                    feature_names=X.columns, 
                    class_names=['Disease', "No Disease"])
    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    return graph

# %%
def evaluate_model(dt_classifier):
    print("Train Accuracy :", accuracy_score(y_train, dt_classifier.predict(X_train)))
    print("Train Confusion Matrix:")
    print(confusion_matrix(y_train, dt_classifier.predict(X_train)))
    print("-"*50)
    print("Test Accuracy :", accuracy_score(y_test, dt_classifier.predict(X_test)))
    print("Test Confusion Matrix:")
    print(confusion_matrix(y_test, dt_classifier.predict(X_test)))

# %% [markdown]
# ### Without setting any hyper-parameters

# %%
dt_default = DecisionTreeClassifier(random_state=42)
dt_default.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
gph = get_dt_graph(dt_default)
Image(gph.create_png())

# %%
evaluate_model(dt_default)
# Out:
# Train Accuracy : 1.0
# Train Confusion Matrix:
# [[106   0]
#  [  0 135]]
# --------------------------------------------------
# Test Accuracy : 0.7377049180327869
# Test Confusion Matrix:
# [[25  7]
#  [ 9 20]]

# %% [markdown]
# ### Controlling the depth of the tree

# %%
# ?DecisionTreeClassifier

# %%
dt_depth = DecisionTreeClassifier(max_depth=3)
dt_depth.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
gph = get_dt_graph(dt_depth) 
Image(gph.create_png())

# %%
evaluate_model(dt_depth)
# Out:
# Train Accuracy : 0.8464730290456431
# Train Confusion Matrix:
# [[ 79  27]
#  [ 10 125]]
# --------------------------------------------------
# Test Accuracy : 0.7377049180327869
# Test Confusion Matrix:
# [[24  8]
#  [ 8 21]]

# %% [markdown]
# ### Specifying minimum samples before split

# %%
dt_min_split = DecisionTreeClassifier(min_samples_split=20)
dt_min_split.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_split=20)

# %%
gph = get_dt_graph(dt_min_split) 
Image(gph.create_png())

# %%
evaluate_model(dt_min_split)
# Out:
# Train Accuracy : 0.9004149377593361
# Train Confusion Matrix:
# [[ 96  10]
#  [ 14 121]]
# --------------------------------------------------
# Test Accuracy : 0.7377049180327869
# Test Confusion Matrix:
# [[26  6]
#  [10 19]]

# %% [markdown]
# ### Specifying minimum samples in leaf node

# %%
dt_min_leaf = DecisionTreeClassifier(min_samples_leaf=20, random_state=42)
dt_min_leaf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(min_samples_leaf=20, random_state=42)

# %%
gph = get_dt_graph(dt_min_leaf)
Image(gph.create_png())

# %%
evaluate_model(dt_min_leaf)
# Out:
# Train Accuracy : 0.8008298755186722
# Train Confusion Matrix:
# [[ 91  15]
#  [ 33 102]]
# --------------------------------------------------
# Test Accuracy : 0.6885245901639344
# Test Confusion Matrix:
# [[25  7]
#  [12 17]]

# %% [markdown]
# ### Using Entropy instead of Gini

# %%
dt_min_leaf_entropy = DecisionTreeClassifier(min_samples_leaf=20, random_state=42, criterion="entropy")
dt_min_leaf_entropy.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_leaf=20,
#                        random_state=42)

# %%
gph = get_dt_graph(dt_min_leaf_entropy)
Image(gph.create_png())

# %%
evaluate_model(dt_min_leaf_entropy)
# Out:
# Train Accuracy : 0.8008298755186722
# Train Confusion Matrix:
# [[ 91  15]
#  [ 33 102]]
# --------------------------------------------------
# Test Accuracy : 0.6885245901639344
# Test Confusion Matrix:
# [[25  7]
#  [12 17]]

# %% [markdown]
# ### Hyper-parameter tuning

# %%
dt = DecisionTreeClassifier(random_state=42)

# %%
from sklearn.model_selection import GridSearchCV

# %%
# Create the parameter grid based on the results of random search 
params = {
    'max_depth': [2, 3, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'criterion': ["gini", "entropy"]
}

# %%
# grid_search = GridSearchCV(estimator=dt, 
#                            param_grid=params, 
#                            cv=4, n_jobs=-1, verbose=1, scoring = "f1")

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=dt, 
                           param_grid=params, 
                           cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
# %%time
grid_search.fit(X_train, y_train)
# Out:
# Fitting 4 folds for each of 50 candidates, totalling 200 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    2.6s
# Wall time: 3 s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    2.9s finished
# GridSearchCV(cv=4, estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
score_df = pd.DataFrame(grid_search.cv_results_)
score_df.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.009480      0.002285         0.004226        0.002953
# 1       0.009380      0.001924         0.003247        0.001347
# 2       0.007026      0.002093         0.006986        0.001347
# 3       0.005829      0.002489         0.005230        0.003494
# 4       0.007163      0.000778         0.003364        0.000528
#
#   param_criterion param_max_depth param_min_samples_leaf  \
# 0            gini               2                      5
# 1            gini               2                     10
# 2            gini               2                     20
# 3            gini               2                     50
# 4            gini               2                    100
#
#                                               params  split0_test_score  \
# 0  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.737705
# 1  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.737705
# 2  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.737705
# 3  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.721311
# 4  {'criterion': 'gini', 'max_depth': 2, 'min_sam...           0.557377
#
#    split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 0           0.783333           0.683333           0.750000         0.738593
# 1           0.783333           0.683333           0.750000         0.738593
# 2           0.766667           0.683333           0.750000         0.734426
# 3           0.766667           0.683333           0.750000         0.730328
# 4           0.550000           0.566667           0.566667         0.560178
#
#    std_test_score  rank_test_score
# 0        0.036008               25
# 1        0.036008               25
# 2        0.031238               27
# 3        0.031612               31
# 4        0.006994               41

# %%
score_df.nlargest(5,"mean_test_score")
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 36       0.005016      0.000496         0.004002        0.001362
# 41       0.006946      0.000490         0.003567        0.000611
# 46       0.006011      0.000241         0.002079        0.000096
# 35       0.009975      0.007793         0.001498        0.001118
# 10       0.004524      0.000539         0.002377        0.000315
#
#    param_criterion param_max_depth param_min_samples_leaf  \
# 36         entropy               5                     10
# 41         entropy              10                     10
# 46         entropy              20                     10
# 35         entropy               5                      5
# 10            gini               5                      5
#
#                                                params  split0_test_score  \
# 36  {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.836066
# 41  {'criterion': 'entropy', 'max_depth': 10, 'min...           0.836066
# 46  {'criterion': 'entropy', 'max_depth': 20, 'min...           0.836066
# 35  {'criterion': 'entropy', 'max_depth': 5, 'min_...           0.819672
# 10  {'criterion': 'gini', 'max_depth': 5, 'min_sam...           0.836066
#
#     split1_test_score  split2_test_score  split3_test_score  mean_test_score  \
# 36           0.816667           0.733333           0.816667         0.800683
# 41           0.816667           0.733333           0.816667         0.800683
# 46           0.816667           0.733333           0.816667         0.800683
# 35           0.850000           0.716667           0.800000         0.796585
# 10           0.866667           0.700000           0.783333         0.796516
#
#     std_test_score  rank_test_score
# 36        0.039683                1
# 41        0.039683                1
# 46        0.039683                1
# 35        0.049459                4
# 10        0.063195                5

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=5, min_samples_leaf=10,
#                        random_state=42)

# %%
dt_best = grid_search.best_estimator_

# %%
evaluate_model(dt_best)
# Out:
# Train Accuracy : 0.8672199170124482
# Train Confusion Matrix:
# [[ 90  16]
#  [ 16 119]]
# --------------------------------------------------
# Test Accuracy : 0.7540983606557377
# Test Confusion Matrix:
# [[24  8]
#  [ 7 22]]

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, dt_best.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76        32
#            1       0.73      0.76      0.75        29
#
#     accuracy                           0.75        61
#    macro avg       0.75      0.75      0.75        61
# weighted avg       0.75      0.75      0.75        61

# %%
gph = get_dt_graph(dt_best)
Image(gph.create_png())

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(random_state=42, n_estimators=10, max_depth=3)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10, random_state=42)

# %%
rf.estimators_[0]
# Out:
# DecisionTreeClassifier(max_depth=3, max_features='auto',
#                        random_state=1608637542)

# %%
sample_tree = rf.estimators_[4]

# %%
gph = get_dt_graph(sample_tree)
Image(gph.create_png(), width=700, height=700)

# %%
gph = get_dt_graph(rf.estimators_[2])
Image(gph.create_png(), width=700, height=700)

# %%
evaluate_model(rf)
# Out:
# Train Accuracy : 0.8755186721991701
# Train Confusion Matrix:
# [[ 88  18]
#  [ 12 123]]
# --------------------------------------------------
# Test Accuracy : 0.8852459016393442
# Test Confusion Matrix:
# [[25  7]
#  [ 0 29]]

# %% [markdown]
# #### Grid search for hyper-parameter tuning

# %%
classifier_rf = RandomForestClassifier(random_state=42, n_jobs=-1)

# %%
# Create the parameter grid based on the results of random search 
params = {
    'max_depth': [1, 2, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'max_features': [2,3,4],
    'n_estimators': [10, 30, 50, 100, 200]
}

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=classifier_rf, param_grid=params, 
                          cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
# %%time
grid_search.fit(X,y)
# Out:
# Fitting 4 folds for each of 375 candidates, totalling 1500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 264 tasks      | elapsed:   13.5s
# [Parallel(n_jobs=-1)]: Done 514 tasks      | elapsed:   26.9s
# [Parallel(n_jobs=-1)]: Done 864 tasks      | elapsed:   46.1s
# [Parallel(n_jobs=-1)]: Done 1314 tasks      | elapsed:  1.2min
# Wall time: 1min 22s
# [Parallel(n_jobs=-1)]: Done 1500 out of 1500 | elapsed:  1.4min finished
# GridSearchCV(cv=4, estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [1, 2, 5, 10, 20],
#                          'max_features': [2, 3, 4],
#                          'min_samples_leaf': [5, 10, 20, 50, 100],
#                          'n_estimators': [10, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
rf_best = grid_search.best_estimator_

# %%
rf_best
# Out:
# RandomForestClassifier(max_depth=10, max_features=4, min_samples_leaf=5,
#                        n_estimators=10, n_jobs=-1, random_state=42)

# %%
evaluate_model(rf_best)
# Out:
# Train Accuracy : 0.8755186721991701
# Train Confusion Matrix:
# [[ 93  13]
#  [ 17 118]]
# --------------------------------------------------
# Test Accuracy : 0.9016393442622951
# Test Confusion Matrix:
# [[27  5]
#  [ 1 28]]

# %% [markdown]
# - Flase negatives are more dangerous to False positives, therefore Recall value must be as close to 100% as possible. in this case Recall is around 93% which is an encouraging factor. So we say our model predicts the people who are having heart disease with a 93% accuracy, helps them preventing death.

# %%
sample_tree = rf_best.estimators_[0]

# %%
gph = get_dt_graph(sample_tree)
Image(gph.create_png())

# %%
gph = get_dt_graph(rf_best.estimators_[0])
Image(gph.create_png(), height=600, width=600)

# %%
gph = get_dt_graph(rf_best.estimators_[1])
Image(gph.create_png(), height=600, width=600)

# %% [markdown]
# ### Variable importance in RandomForest and Decision trees

# %%
classifier_rf = RandomForestClassifier(random_state=42, n_jobs=-1, max_depth=10, max_features=4, min_samples_leaf=5,
                       n_estimators=10, oob_score=True)

# %%
classifier_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=10, max_features=4, min_samples_leaf=5,
#                        n_estimators=10, n_jobs=-1, oob_score=True,
#                        random_state=42)

# %%
classifier_rf.oob_score_
# Out:
# 0.7925311203319502

# %%
classifier_rf.feature_importances_
# Out:
# array([0.04276588, 0.06038053, 0.23842345, 0.0467922 , 0.0292295 ,
#        0.        , 0.01540376, 0.13747781, 0.09232541, 0.04970348,
#        0.03119352, 0.13550262, 0.12080184])

# %%
imp_df = pd.DataFrame({
    "Varname": X_train.columns,
    "Imp": classifier_rf.feature_importances_
})

# %%
imp_df.sort_values(by="Imp", ascending=False)
# Out:
#      Varname       Imp
# 2         cp  0.238423
# 7    thalach  0.137478
# 11        ca  0.135503
# 12      thal  0.120802
# 8      exang  0.092325
# 1        sex  0.060381
# 9    oldpeak  0.049703
# 3   trestbps  0.046792
# 0        age  0.042766
# 10     slope  0.031194
# 4       chol  0.029229
# 6    restecg  0.015404
# 5        fbs  0.000000

# %%
# Create the parameter grid based on the results of random search 
params = {
    'max_depth': [1, 2, 5, 10, 20],
    'min_samples_leaf': [5, 10, 20, 50, 100],
    'max_features': [2,3,4],
    'n_estimators': [10, 30, 50, 100, 200]
}

# %%
# Instantiate the grid search model
grid_search = GridSearchCV(estimator=classifier_rf, param_grid=params, 
                          cv=4, n_jobs=-1, verbose=1, scoring = "accuracy")

# %%
# %%time
grid_search.fit(X,y)
# Out:
# Fitting 4 folds for each of 375 candidates, totalling 1500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 216 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 466 tasks      | elapsed:   30.5s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:   54.6s
# [Parallel(n_jobs=-1)]: Done 1266 tasks      | elapsed:  1.5min
# Wall time: 1min 44s
# [Parallel(n_jobs=-1)]: Done 1500 out of 1500 | elapsed:  1.7min finished
# GridSearchCV(cv=4,
#              estimator=RandomForestClassifier(max_depth=10, max_features=4,
#                                               min_samples_leaf=5,
#                                               n_estimators=10, n_jobs=-1,
#                                               oob_score=True, random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [1, 2, 5, 10, 20],
#                          'max_features': [2, 3, 4],
#                          'min_samples_leaf': [5, 10, 20, 50, 100],
#                          'n_estimators': [10, 30, 50, 100, 200]},
#              scoring='accuracy', verbose=1)

# %%
rf_best = grid_search.best_estimator_
rf_best
# Out:
# RandomForestClassifier(max_depth=10, max_features=4, min_samples_leaf=5,
#                        n_estimators=10, n_jobs=-1, oob_score=True,
#                        random_state=42)

# %%
evaluate_model(rf_best)
# Out:
# Train Accuracy : 0.8755186721991701
# Train Confusion Matrix:
# [[ 93  13]
#  [ 17 118]]
# --------------------------------------------------
# Test Accuracy : 0.9016393442622951
# Test Confusion Matrix:
# [[27  5]
#  [ 1 28]]
